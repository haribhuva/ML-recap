# %% [markdown]
# # Estimate the unit sales of Walmart retail goods

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import openpyxl

# %%
item_details = pd.read_excel('archive/item_details.xlsx')
item_details.sample(10)
# Out:
#            item_id     category_of_item       class  perishable
# 2654  item_1464186            beverages  class_1190           0
# 2877  item_1584300    hygeine_utilities  class_7780           0
# 1644  item_1114914   cleaning_utilities  class_3038           0
# 983    item_794245        grocery_items  class_1010           0
# 2707  item_1471460          dairy_items  class_2128           1
# 387    item_362035        grocery_items  class_1044           0
# 944    item_765517        grocery_items  class_1060           0
# 2754  item_1473484   other_farm_produce  class_2016           1
# 1175   item_872308        grocery_items  class_1034           0
# 2251  item_1386120  kitchen_utilities_2  class_6246           0

# %%
location_details = pd.read_excel('archive/location_details.xlsx')
location_details.sample(10)
# Out:
#     location_id       city           state type  cluster
# 18  location_19     Indore  Madhya Pradesh    C       15
# 49  location_50    Gurgaon         Haryana    A       14
# 26  location_27     Mysore       Karnataka    D        1
# 23  location_24     Mumbai     Maharashtra    D        1
# 3    location_4  Bengaluru       Karnataka    D        9
# 51  location_52    Chennai      Tamil Nadu    A       11
# 50  location_51     Mumbai     Maharashtra    A       17
# 6    location_7  Bengaluru       Karnataka    D        8
# 48  location_49  Bengaluru       Karnataka    A       11
# 47  location_48  Bengaluru       Karnataka    A       14

# %%
sample_submission = pd.read_csv('archive/sample_submission.csv')
sample_submission.sample(10)
# Out:
#                 id  unit_sales
# 3335526    3335526           0
# 23411994  23697798           0
# 10429520  10429520           0
# 13990570  14053700           0
# 19452078  19644207           0
# 11272406  11272406           0
# 16486050  16608055           0
# 15648641  15750986           0
# 14275273  14345668           0
# 5254011    5254011           0

# %%
test = pd.read_csv('archive/test.csv')
test.sample(10)
# Out:
#                 id        date   locationId       item_id  onpromotion
# 4808364    4808364  2019-02-16  location_50   item_157956        False
# 9072127    9072127  2019-03-29  location_34  item_1695887        False
# 15786580  15893805  2019-06-01  location_53  item_2010667        False
# 20091188  20298003  2019-07-13  location_29   item_457556        False
# 13182226  13225791  2019-05-07  location_43  item_1473509        False
# 19655554  19852729  2019-07-09  location_11  item_1333225         True
# 13866725  13927361  2019-05-14  location_26  item_1152355        False
# 3806584    3806584  2019-02-07   location_9  item_1584576         True
# 4573736    4573736  2019-02-14  location_33  item_1695983         True
# 7418462    7418462  2019-03-13  location_40   item_608035        False

# %%
train_transactions = pd.read_excel('archive/train_transactions.xlsx')
train_transactions.sample(10)
# Out:
#             date location_identifier  transactions
# 28292 2016-09-01         location_51          1682
# 856   2015-01-20         location_32           801
# 28800 2016-09-12         location_39          1151
# 19273 2016-02-21         location_15          1202
# 61088 2018-06-16         location_10           859
# 36582 2017-02-23         location_33           880
# 61503 2018-06-24          location_1          1705
# 52839 2018-01-12         location_27          1366
# 3606  2015-03-21         location_18          1396
# 26676 2016-07-29         location_37          1490

# %%
train = pd.read_csv('archive/train.csv')
train.sample(10)
# Out:
# C:\Users\harib\AppData\Local\Temp\ipykernel_496\4003363557.py:1: DtypeWarning: Columns (0: onpromotion) have mixed types. Specify dtype option on import or set low_memory=False.
#   train = pd.read_csv('archive/train.csv')
#                 date   locationId       item_id  unit_sales onpromotion
# 83383870  2018-06-27  location_53   item_954796       5.000       False
# 47957041  2017-06-01  location_41   item_519560       2.772       False
# 86849835  2018-08-02  location_42  item_1943792       2.000       False
# 89512533  2018-08-30  location_27  item_1967914      11.000       False
# 45830518  2017-05-01  location_16   item_368419       6.000       False
# 85428655  2018-07-19   location_6   item_374464       6.000       False
# 91047455  2018-09-15  location_22  item_1159598       4.000       False
# 73322970  2018-03-14  location_32  item_1940026       1.000       False
# 74357331  2018-03-25  location_32   item_902198       1.000       False
# 11308285  2015-09-18  location_28   item_315322       2.000         NaN

# %%
print(f"Item details shape: {item_details.shape}")
print(f"Location details shape: {location_details.shape}")
print(f"Sample submission shape: {sample_submission.shape}")
print(f"Test data shape: {test.shape}")
print(f"Train transactions shape: {train_transactions.shape}")
print(f"Train data shape: {train.shape}")
# Out:
# Item details shape: (4100, 4)
# Location details shape: (54, 5)
# Sample submission shape: (23517680, 2)
# Test data shape: (23517680, 5)
# Train transactions shape: (71391, 3)
# Train data shape: (101688779, 5)

# %%
print(f"Item details columns: {item_details.columns}")
print(f"Location details columns: {location_details.columns}")
print(f"Sample submission columns: {sample_submission.columns}")
print(f"Test data columns: {test.columns}")
print(f"Train transactions columns: {train_transactions.columns}")
print(f"Train data columns: {train.columns}")
# Out:
# Item details columns: Index(['item_id', 'category_of_item', 'class', 'perishable'], dtype='str')
# Location details columns: Index(['location_id', 'city', 'state', 'type', 'cluster'], dtype='str')
# Sample submission columns: Index(['id', 'unit_sales'], dtype='str')
# Test data columns: Index(['id', 'date', 'locationId', 'item_id', 'onpromotion'], dtype='str')
# Train transactions columns: Index(['date', 'location_identifier', 'transactions'], dtype='str')
# Train data columns: Index(['date', 'locationId', 'item_id', 'unit_sales', 'onpromotion'], dtype='str')

# %%
print(len(train['item_id'].unique()))
print(len(train['locationId'].unique()))
# Out:
# 3890
# 53

# %%
train.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 101688779 entries, 0 to 101688778
# Data columns (total 5 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   date         str
#  1   locationId   str
#  2   item_id      str
#  3   unit_sales   float64
#  4   onpromotion  object
# dtypes: float64(1), object(1), str(3)
# memory usage: 3.8+ GB

# %%
test.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 23517680 entries, 0 to 23517679
# Data columns (total 5 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           int64
#  1   date         str
#  2   locationId   str
#  3   item_id      str
#  4   onpromotion  bool
# dtypes: bool(1), int64(1), str(3)
# memory usage: 740.1 MB

# %%
train.duplicated().sum()
# Out:
# np.int64(10044)

# %%
test.duplicated().sum()
# Out:
# np.int64(0)

# %%
train.isnull().sum()
# Out:
# date                  0
# locationId            0
# item_id               0
# unit_sales            0
# onpromotion    21657651
# dtype: int64

# %%
test.isnull().sum()
# Out:
# id             0
# date           0
# locationId     0
# item_id        0
# onpromotion    0
# dtype: int64
